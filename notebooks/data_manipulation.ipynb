# %%
import pandas as pd

# %%
import os
import openai
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']

chat = ChatOpenAI(temperature=0.0)

pre_match_template = """ From the query provided translate to a filter dataset using only the following features, once selected pick a number for each variable to filter:

Variable		Definition
player			player ID
Position		position ID
Name			player name
Team			team ID
League			league number
Season			season number
Minutes			minutes played at position
Attack			0-99 attacking output rating
DefQual			0-99 defending quality rating
DefQuant		0-99 defending quantity rating
BallRet			0-99 ball retention rating
Disrupt			0-99 disrupt style rating
Recover			0-99 recover style rating
Aerial			0-99 aerials style rating
Link			0-99 linking up style rating
Forward			0-99 passing toward goal style rating
Carry			0-99 dribbles/carries style rating
Receive			0-99 receiving in the box style rating
Shoot			0-99 shooting style rating
Set			0-99 aerial duels from dead balls rating
Dribble			0-99 ground duels in possession rating
Tackle			0-99 ground duels out of possession rating
Open_Foot		0-99 non-headers in open play shooting/saving rating
Open_Head		0-99 headers in open play shooting/saving rating
Dead_Foot		0-99 non-headers from dead balls shooting/saving rating
Dead_Head		0-99 headers from dead balls shooting/saving rating
Direct			0-99 direct free kicks shooting/saving rating
goal			goal flag
goalpershot		non-penalty goals per shot
xgpershot		xG per shot
pctxgpass		share of ball progression xG from passing
pctxgrecv		share of ball progression xG from receiving
smgpi			share of moves ending in non-penalty goals involving player while on the pitch
smspi			share of moves ending in shots involving player while on the pitch
stxgpi			share of total xG from moves ending in shots involving player while on the pitch
avgawayplaytime		average playing time away
avghomeplaytime		average playing time at home
homeoxg95min		xG from shots at home per 95 minutes
awayoxg95min		xG from shots away per 95 minutes
homexga95		home xG against per 95 minutes
awayxga95		away xG against per 95 minutes
homexcs95		home expected clean sheets per 95 minutes
awayxcs95		away expected clean sheets per 95 minutes
Age			player age
Height			player height
Weight			player weight
Birthdate		player birthdate
tabb			team abbreviation
Pass1			style rating for passes of 0m to 10m
Pass2			style rating for passes of 10m to 20m
Pass3			style rating for passes of 20m or more
Cross			0-99 crossing style rating
a_Hot			age-limited hot flag
a_Cold			age-limited cold flag
a_Breakout		age-limited breakout season flag
a_Underused		age-limited underused flag
a_Prospect		age-limited young prospect flag
Attack_SC		attacking output rating from shot creation model only (0-99 scale)
Attack_BP		attacking output rating from ball progression model only (0-99 scale)
xG_Receive_BP		raw xG in ball progression model from receiving
xG_Pass_BP		raw xG in ball progression model from passing
xG_Indv_BP		raw xG in ball progression model from individual play
xG_Indv_Takenon_BP	raw xG in ball progression model from take-ons
xG_Indv_Tackle_BP	raw xG in ball progression model from tackles
xG_Indv_Inter_BP	raw xG in ball progression model from interceptions
xG_Indv_Aerial_BP	raw xG in ball progression model from aerials
xG_Indv_Carry_BP	raw xG in ball progression model from carries
xG_Indv_Loose_BP	raw xG in ball progression model from picking up loose balls
xG_Cntr_SC		raw xG contributions in shot creation model
xG_Cross_SC		raw xG crosses in shot creation model
xG_Shots		raw xG of shots taken
xG_Open_SC		raw xG contributions in shot creation model in open play
xG_Dead_SC		raw xG contributions in shot creation model from dead balls
xG_Open_BP		raw xG contributions in ball progression model in open play
xG_Dead_BP		raw xG contributions in ball progression model from dead balls
xGFAR			xG for above median replacement player at position per 95 minutes
xGAAR			xG against above median replacement player at position per 95 minutes
xGDAR			xG difference above median replacement player at position per 95 minutes
Attack_OP_SC		0-99 attacking output rating for shot creation in open play
Attack_OP_BP		0-99 attacking output rating for ball progression in open play
Attack_DB_SC		0-99 attacking output rating for shot creation from dead balls
Attack_DB_BP		0-99 attacking output rating for ball progression from dead balls


\nUser Query: '{text}'\nSpecific Query or Numerical Translation only using the provided features: """ 

prompt_template = ChatPromptTemplate.from_template(pre_match_template)

text = "top players from brazil that are ready for premier league"
customer_messages = prompt_template.format_messages(text=text)
response = chat(customer_messages)
response.content
# Out:
# 'Filter dataset using the following features:\n- player\n- Position\n- Name\n- Team\n- League\n- Season\n- Minutes\n- Attack\n- DefQual\n- DefQuant\n- BallRet\n- Disrupt\n- Recover\n- Aerial\n- Link\n- Forward\n- Carry\n- Receive\n- Shoot\n- Set\n- Dribble\n- Tackle\n- Open_Foot\n- Open_Head\n- Dead_Foot\n- Dead_Head\n- Direct\n- goal\n- goalpershot\n- xgpershot\n- pctxgpass\n- pctxgrecv\n- smgpi\n- smspi\n- stxgpi\n- avgawayplaytime\n- avghomeplaytime\n- homeoxg95min\n- awayoxg95min\n- homexga95\n- awayxga95\n- homexcs95\n- awayxcs95\n- Age\n- Height\n- Weight\n- Birthdate\n- tabb\n- Pass1\n- Pass2\n- Pass3\n- Cross\n- a_Hot\n- a_Cold\n- a_Breakout\n- a_Underused\n- a_Prospect\n- Attack_SC\n- Attack_BP\n- xG_Receive_BP\n- xG_Pass_BP\n- xG_Indv_BP\n- xG_Indv_Takenon_BP\n- xG_Indv_Tackle_BP\n- xG_Indv_Inter_BP\n- xG_Indv_Aerial_BP\n- xG_Indv_Carry_BP\n- xG_Indv_Loose_BP\n- xG_Cntr_SC\n- xG_Cross_SC\n- xG_Shots\n- xG_Open_SC\n- xG_Dead_SC\n- xG_Open_BP\n- xG_Dead_BP\n- xGFAR\n- xGAAR\n- xGDAR\n- Attack_OP_SC\n- Attack_OP_BP\n- Attack_DB_SC\n- Attack_DB_BP\n\nNumerical Translation:\n- Country: Brazil\n- League: Premier League'

# %%
ChatOpenAI()

# %%
# Instantiate a LLM
from pandasai import SmartDataframe
from pandasai.llm import OpenAI
llm = OpenAI(api_token=openai.api_key)

df = pd.read_csv('../data/processed/ENG1_GPT2_clean.csv', index_col=0)

# %%
# Creating Python lists based on the revised categorization

# 1. Player Identification and Demographics
player_identification_demographics = ['player', 'Position', 'Name', 'Team', 'League', 'Season', 'Age', 'Height', 
                                      'Weight', 'Birthdate', 'tabb']

# 2. Playing Time and Performance Metrics
playing_time_performance_metrics = ['Minutes', 'avgawayplaytime', 'avghomeplaytime', 'homeoxg95min', 'awayoxg95min', 
                                    'homexga95', 'awayxga95', 'homexcs95', 'awayxcs95', 'xGFAR', 'xGAAR', 'xGDAR', 
                                    'goal', 'goalpershot', 'xgpershot', 'pctxgpass', 'pctxgrecv', 'smgpi', 'smspi', 
                                    'stxgpi']

# 3. Attacking Skills and Style Ratings
attacking_skills_style_ratings = ['Attack', 'Forward', 'Carry', 'Receive', 'Shoot', 'Set', 'Dribble', 'Attack_SC', 
                                  'Attack_BP', 'Attack_OP_SC', 'Attack_OP_BP', 'Attack_DB_SC', 'Attack_DB_BP', 
                                  'xG_Receive_BP', 'xG_Pass_BP', 'xG_Indv_BP', 'xG_Indv_Takeon_BP', 'xG_Cntr_SC', 
                                  'xG_Cross_SC', 'xG_Shots', 'xG_Open_SC', 'xG_Dead_SC', 'xG_Open_BP', 'xG_Dead_BP']

# 4. Defensive Skills and Style Ratings
defensive_skills_style_ratings = ['DefQual', 'DefQuant', 'BallRet', 'Disrupt', 'Recover', 'Aerial', 'Tackle', 
                                  'xG_Indv_Tackle_BP', 'xG_Indv_Inter_BP', 'xG_Indv_Aerial_BP']

# 5. Play Style and Specialties
play_style_specialties = ['Link', 'Pass1', 'Pass2', 'Pass3', 'Cross', 'Open_Foot', 'Open_Head', 'Dead_Foot', 
                          'Dead_Head', 'Direct', 'xG_Indv_Carry_BP', 'xG_Indv_Loose_BP']

# 6. Age-Related Traits and Trends
age_related_traits_trends = ['a_Hot', 'a_Cold', 'a_Breakout', 'a_Underused', 'a_Prospect']

# %%
features = df[attacking_skills_style_ratings].describe().loc[['min', 'mean', 'max']].to_json()

# %%
import os
import openai
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']

chat = ChatOpenAI(temperature=0.0)

pre_match_template = """ From the following features: {features} provide a numerical value based on the following text: {text}""" 

prompt_template = ChatPromptTemplate.from_template(pre_match_template)

text = "top players from brazil that are ready for premier league"
customer_messages = prompt_template.format_messages(features=features, text=text)
response = chat(customer_messages)
response.content
# Out:
# 'Based on the given features, it is not possible to provide a numerical value for the top players from Brazil who are ready for the Premier League. The features provided are related to player performance metrics, but they do not specify the nationality or readiness for the Premier League.'

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyD1k_A9wwpJIuSfI0jQq-yw7PmsQVjUry0")

model = genai.GenerativeModel('gemini-pro')

# %%
prompt = f"Based on the following query pick the most relevant features to filter the dataframe: {text}, use natural language that allow to understand how to filter the dataframe to get the desired output from this features: {features[0:3]}, always pick great than and higher than using the most relevant features. Start the answer by: SELECT "

# %%
response = model.generate_content(prompt)

# %%
response.text
# Out:
# "To filter the dataframe and obtain the top Brazilian players who are ready for the Premier League, you can use the following query:\n\n```\nSELECT *\nFROM players\nWHERE nationality = 'Brazil'\nAND skill_level > 85\nAND experience > 5\nAND age < 28\nAND position IN ('Forward', 'Midfielder', 'Defender')\nORDER BY skill_level DESC;\n```\n\nLet's break down the query:\n\n- We start with the `SELECT *` statement, which means we want to select all columns for the resulting rows.\n\n- The `FROM players` part specifies that we're working with the 'players' table.\n\n- The `WHERE` clause contains the filtering conditions:\n  - `nationality = 'Brazil'`: This condition selects players whose nationality is 'Brazil'.\n  - `skill_level > 85`: This condition selects players with a skill level greater than 85.\n  - `experience > 5`: This condition selects players with more than 5 years of experience.\n  - `age < 28`: This condition selects players who are younger than 28 years old.\n  - `position IN ('Forward', 'Midfielder', 'Defender')`: This condition selects players whose position is either 'Forward', 'Midfielder', or 'Defender'.\n\n- The `ORDER BY skill_level DESC` clause sorts the results in descending order based on the skill_level column. This means that the players with the highest skill level will appear first in the results.\n\nBy applying these filters, you can extract the top Brazilian players who possess the necessary skills, experience, and physical attributes to compete in the Premier League."

# %%
df = SmartDataframe(df, config={"llm": llm})

# %%
df.chat(response.text)
# Out:
#            player Position                                           Name  \
# 185544  1284205.0      RCB                Gustavo Martins de Souza Santos
# 5882       4112.0       LB                         Danilo Fernando Avelar
# 28113     15765.0    CF/ST  Andre Luiz Barretto Silva Barretto Silva Lima
# 131960   258412.0      LCB                    Iago Justen Maidana Martins
# 126626   238819.0       LB                Gustavo Henrique Furtado Scarpa
# 184402  1217740.0      RCB                 Joaquim Henrique Pereira Silva
# 177702  1000972.0       RB                        Gabriel Vinicius Menino
# 11271      6447.0      RCB                  Felipe Augusto Felipe Santana
# 47742     29077.0       DM                          Moises Lima Magalhaes
# 138795   288342.0    CF/ST                           Bruno Henrique Pinto
#
#                           Team League  Season  Minutes  Attack  DefQual  \
# 185544                  Gremio   BRA1    2023      432    99.0     39.0
# 5882           America Mineiro   BRA1    2023      716    99.0     62.0
# 28113                  Vitoria   BRA1    2017      784    99.0     52.0
# 131960  Clube Atletico Mineiro   BRA1    2019      399    99.0     66.0
# 126626               Palmeiras   BRA1    2020      370    98.0     28.0
# 184402                  Cuiaba   BRA1    2022      377    98.0      7.0
# 177702               Palmeiras   BRA1    2021      484    98.0     74.0
# 11271   Clube Atletico Mineiro   BRA1    2017      836    98.0     48.0
# 47742                Palmeiras   BRA1    2016     1414    98.0     74.0
# 138795                Flamengo   BRA1    2019     1299    97.0     43.0
#
#         DefQuant  ...  xG_Dead_SC  xG_Open_BP  xG_Dead_BP  xGFAR  xGAAR  \
# 185544        98  ...    0.387233    0.268542    0.278813   0.10   0.05
# 5882          76  ...    0.840744    0.626952    0.644995   0.12   0.04
# 28113         92  ...    1.003718    2.228650    0.385198   0.18   0.01
# 131960         8  ...    0.883469    0.019499    0.478656   0.10  -0.03
# 126626         2  ...    0.113593    0.603688    0.284670   0.11  -0.06
# 184402        88  ...    0.494324    0.089610    0.268928   0.08  -0.14
# 177702        75  ...    0.062945    0.700436    0.175906   0.09   0.05
# 11271         93  ...    1.073774    0.121599    0.805251   0.07   0.04
# 47742         91  ...    0.351473    2.240264    0.468504   0.12   0.05
# 138795        51  ...    0.962518    3.740709    0.546264   0.16   0.00
#
#         xGDAR  Attack_OP_SC  Attack_OP_BP  Attack_DB_SC  Attack_DB_BP
# 185544   0.15          99.0          99.0          99.0          97.0
# 5882     0.16          83.0          81.0          99.0          99.0
# 28113    0.19          98.0          99.0          97.0          95.0
# 131960   0.07           8.0           5.0          99.0          99.0
# 126626   0.05          99.0          99.0          95.0          97.0
# 184402  -0.06          98.0          68.0          99.0          92.0
# 177702   0.14          99.0          98.0          98.0          90.0
# 11271    0.11          18.0          19.0          98.0          95.0
# 47742    0.17          97.0          99.0          96.0          98.0
# 138795   0.16          99.0          96.0          97.0          81.0
#
# [10 rows x 85 columns]

# %%
# Out:
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nAll objects passed were None\n'

# %%
prompt_template.format_messages()

# %%
text = "top players from brazil that are ready for premier league"
customer_messages = prompt_template.format_messages(text=text)
response = chat(customer_messages)
response.content

# %%
# Example usage
user_query = "Show me the best attacking players"
specific_query = handle_user_query(user_query)

# Use `specific_query` to filter or query your dataframe
# (This part depends on your dataframe structure and the query format)

# %%
chat = ChatOpenAI(temperature=0.0)

prompt_template = """\ 

"""
text = ""
customer_messages = prompt_template.format_messages(text=text)
response = chat(customer_messages)

# %%
customer_messages = prompt_template.format_messages(text=text)
response = chat(customer_messages)

# %%
def get_completion(prompt, model="gpt-3.5-turbo-1106"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.0, 
    )
    return response.choices[0].message["content"]

# %% [markdown]
# # Clean dataset

# %%
# preprocess.py
# process the dataset and return a clean dataframe

import pandas as pd
from pandasai import SmartDataframe

# Instantiate a LLM
from pandasai.llm import OpenAI
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

llm = OpenAI(api_token=openai.api_key)

df = pd.read_csv('../data/raw/ENG1_GPT2.csv')

df.dropna(subset=['Name', 'Team'], inplace=True)
df = df[df['Minutes'] >= 360]
df.reset_index(drop=True, inplace=True)
df_smart = SmartDataframe(df, config={"llm": llm})
df_smart_input = df_smart.impute_missing_values()

df_smart_input.to_csv('../data/processed/ENG1_GPT2_clean.csv')

# %%
# Instantiate a LLM
from pandasai.llm import OpenAI
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

llm = OpenAI(api_token=openai.api_key)

df = pd.read_csv('../data/raw/ENG1_GPT2.csv')

# %%
from pandasai.prompts import AbstractPrompt


class MyCustomPrompt(AbstractPrompt):
    template = """You are given a dataframe with the following columns: ['player', 'Position', 'Name', 'Team', 'League', 'Season', 'Minutes',
       'Attack', 'DefQual', 'DefQuant', 'BallRet', 'Disrupt', 'Recover',
       'Aerial', 'Link', 'Forward', 'Carry', 'Receive', 'Shoot', 'Open', 'Set',
       'Dribble', 'Tackle', 'Open_Foot', 'Open_Head', 'Dead_Foot', 'Dead_Head',
       'Direct', 'goal', 'goalpershot', 'xgpershot', 'pctxgpass', 'pctxgrecv',
       'smgpi', 'smspi', 'stxgpi', 'avghomeplaytime', 'avgawayplaytime',
       'homeoxg95min', 'awayoxg95min', 'homexga95', 'awayxga95', 'homexcs95',
       'awayxcs95', 'Age', 'Height', 'Weight', 'posrank', 'sorder',
       'Birthdate', 'tabb', 'Pass1', 'Pass2', 'Pass3', 'Cross', 'a_Hot',
       'a_Cold', 'a_Breakout', 'a_Underused', 'a_Prospect', 'Attack_SC',
       'Attack_BP', 'xG_Receive_BP', 'xG_Pass_BP', 'xG_Indv_BP',
       'xG_Indv_Takeon_BP', 'xG_Indv_Tackle_BP', 'xG_Indv_Inter_BP',
       'xG_Indv_Aerial_BP', 'xG_Indv_Carry_BP', 'xG_Indv_Loose_BP',
       'xG_Cntr_SC', 'xG_Cross_SC', 'xG_Shots', 'xG_Open_SC', 'xG_Dead_SC',
       'xG_Open_BP', 'xG_Dead_BP', 'xGFAR', 'xGAAR', 'xGDAR', 'Attack_OP_SC',
       'Attack_OP_BP', 'Attack_DB_SC', 'Attack_DB_BP'], intepret the queries to translate questions into variables in the dataframe and analyze the dataset

{conversation}
"""

# %%
df.dropna(subset=['Name', 'Team'], inplace=True)
df = df[df['Minutes'] >= 360]
df.reset_index(drop=True, inplace=True)
df_smart = SmartDataframe(df, config={"llm": llm})
df_smart_input = df_smart.impute_missing_values()

# %%
df_smart_input.chat('find the best players in xg and atack features')
# Out:
# "Unfortunately, I was not able to answer your question, because of the following error:\n\nname 'df' is not defined\n"

# %%
df.isna().sum()
# Out:
# player             0
# Position           0
# Name               0
# Team               0
# League             0
#                 ...
# xGDAR             79
# Attack_OP_SC       0
# Attack_OP_BP       0
# Attack_DB_SC    1176
# Attack_DB_BP    1176
# Length: 85, dtype: int64

# %%
df_smart.isna().sum()
# Out:
# player             0
# Position           0
# Name               0
# Team               0
# League             0
#                 ...
# xGDAR             79
# Attack_OP_SC       0
# Attack_OP_BP       0
# Attack_DB_SC    1176
# Attack_DB_BP    1176
# Length: 85, dtype: int64

# %%
df_smart_input.isna().sum()
# Out:
# player          0
# Position        0
# Name            0
# Team            0
# League          0
#                ..
# xGDAR           0
# Attack_OP_SC    0
# Attack_OP_BP    0
# Attack_DB_SC    0
# Attack_DB_BP    0
# Length: 85, dtype: int64

# %%
import os
import openai
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']


def get_completion(prompt, model="gpt-3.5-turbo-1106"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.0, 
    )
    return response.choices[0].message["content"]

chat = ChatOpenAI(temperature=0.5)

pre_match_template = """\
Your job is to translate questions and queries into objective search in the dataset,
 the data contains information about players and statistics relative to the premier league, every query needs to be translated into an objevtive question that can be look using only this columns of the dataset:

Variable		Definition
Player			player ID
Position		position ID
Name			player name
Team			team ID
League			league number
Season			season number
Minutes			minutes played at position
Attack			0-99 attacking output rating
DefQual			0-99 defending quality rating
DefQuant		0-99 defending quantity rating
BallRet			0-99 ball retention rating
Disrupt			0-99 disrupt style rating
Recover			0-99 recover style rating
Aerial			0-99 aerials style rating
Link			0-99 linking up style rating
Forward			0-99 passing toward goal style rating
Carry			0-99 dribbles/carries style rating
Receive			0-99 receiving in the box style rating
Shoot			0-99 shooting style rating
Set			0-99 aerial duels from dead balls rating
Dribble			0-99 ground duels in possession rating
Tackle			0-99 ground duels out of possession rating
Open_Foot		0-99 non-headers in open play shooting/saving rating
Open_Head		0-99 headers in open play shooting/saving rating
Dead_Foot		0-99 non-headers from dead balls shooting/saving rating
Dead_Head		0-99 headers from dead balls shooting/saving rating
Direct			0-99 direct free kicks shooting/saving rating
Goal			goal flag
GoalperShot		non-penalty goals per shot
xGperShot		xG per shot
pctxgpass		share of ball progression xG from passing
pctgrecv		share of ball progression xG from receiving
smgpi			share of moves ending in non-penalty goals involving player while on the pitch
smspi			share of moves ending in shots involving player while on the pitch
stxgpi			share of total xG from moves ending in shots involving player while on the pitch
avgawayplaytime		average playing time away
avghomeplaytime		average playing time at home
homeoxg95min		xG from shots at home per 95 minutes
awayxg95min		xG from shots away per 95 minutes
homexga95		home xG against per 95 minutes
awayxga95		away xG against per 95 minutes
homexcs95		home expected clean sheets per 95 minutes
awayxcs95		away expected clean sheets per 95 minutes
Age			player age
Height			player height
Weight			player weight
Birthdate		player birthdate
tabb			team abbreviation
Pass1			style rating for passes of 0m to 10m
Pass2			style rating for passes of 10m to 20m
Pass3			style rating for passes of 20m or more
Cross			0-99 crossing style rating
a_Hot			age-limited hot flag
a_Cold			age-limited cold flag
a_Breakout		age-limited breakout season flag
a_Underused		age-limited underused flag
a_Prospect		age-limited young prospect flag
Attack_SC		attacking output rating from shot creation model only (0-99 scale)
Attack_BP		attacking output rating from ball progression model only (0-99 scale)
xG_Receive_BP		raw xG in ball progression model from receiving
xG_Pass_BP		raw xG in ball progression model from passing
xG_Indv_BP		raw xG in ball progression model from individual play
xG_Indv_Takenon_BP	raw xG in ball progression model from take-ons
xG_Indv_Tackle_BP	raw xG in ball progression model from tackles
xG_Indv_Inter_BP	raw xG in ball progression model from interceptions
xG_Indv_Aerial_BP	raw xG in ball progression model from aerials
xG_Indv_Carry_BP	raw xG in ball progression model from carries
xG_Indv_Loose_BP	raw xG in ball progression model from picking up loose balls
xG_Cntr_SC		raw xG contributions in shot creation model
xG_Cross_SC		raw xG crosses in shot creation model
xG_Shots		raw xG of shots taken
xG_Open_SC		raw xG contributions in shot creation model in open play
xG_Dead_SC		raw xG contributions in shot creation model from dead balls
xG_Open_BP		raw xG contributions in ball progression model in open play
xG_Dead_BP		raw xG contributions in ball progression model from dead balls
xGFAR			xG for above median replacement player at position per 95 minutes
xGAAR			xG against above median replacement player at position per 95 minutes
xGDAR			xG difference above median replacement player at position per 95 minutes
Attack_OP_SC		0-99 attacking output rating for shot creation in open play
Attack_OP_BP		0-99 attacking output rating for ball progression in open play
Attack_DB_SC		0-99 attacking output rating for shot creation from dead balls
Attack_DB_BP		0-99 attacking output rating for ball progression from dead balls

The metric needs to be choosen from the list of variables and you can select either one or several features to be used as a metric.

The structure of the query needs to have the following format:

Create a table with the the top five players in attack, provide: position, name, team, league, minutes, attack

Translate the following query: {text}
""" 

prompt_template = ChatPromptTemplate.from_template(pre_match_template)

text = "top players from brazil that are ready for premier league"
customer_messages = prompt_template.format_messages(text=text)
response = chat(customer_messages)
response.content

# %%
df_smart_input.chat(response.content)
# Out:
# "Unfortunately, I was not able to answer your question, because of the following error:\n\n'Country'\n"

# %%
df_smart_input.chat('Create a table with the the top five players in attack, provide: position, name, team, league, minutes, metric')
# Out:
#        Position                             Name                 Team League
# 355042      RCB                        Max Dyche     Northampton Town   ENG4  \
# 90930    RM/RWB  Carlos Darwin Quintero Villalba              America   COL1
# 352054       RW                   Shayden Morris       Fleetwood Town   ENG3
# 207571      LCB            Mario Hermoso Canseco      Atletico Madrid    UCL
# 64212       LCB                Igor Rossi Branco  Heart Of Midlothian    UEL
#
#         Minutes  Attack
# 355042      154    99.0
# 90930       161    99.0
# 352054      119    99.0
# 207571      169    99.0
# 64212       260    99.0

# %%
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
season_last_year = {
    '2016': 2016,
    '2017': 2017,
    '2018': 2018,
    '2019': 2019,
    '2020': 2020,
    '2021': 2021,
    '2022': 2022,
    '2023': 2023,
    '2024': 2024,
    '2016-17': 2017,
    '2017-18': 2018,
    '2018-19': 2019,
    '2019-20': 2020,
    '2020-21': 2021,
    '2021-22': 2022,
    '2022-23': 2023,
    '2023-24': 2024,
}

# %%
df_eng['Season'] = df_eng['Season'].map(season_last_year)

# %%
df_eng['Season'].unique()
# Out:
# array([2020, 2019, 2018, 2017, 2023, 2022, 2021, 2024, 2016])

# %%
df_eng.to_csv('../data/raw/ENG1_GPT2.csv', index=False)

# %%
df = pd.read_csv('../data/processed/processed_stats_season_p1.csv')

# %%
df.columns
# Out:
# Index(['matches', 'goals', 'assists', 'shots', 'headShots', 'yellowCards',
#        'redCards', 'directRedCards', 'penalties', 'linkupPlays',
#        ...
#        'newSuccessfulDribbles', 'lateralPasses', 'successfulLateralPasses',
#        'team_id', 'season_id', 'competition_id', 'officialName', 'name',
#        'league_name', 'transfermarkt_id'],
#       dtype='object', length=103)

# %%
grouped_df = df.groupby('league_name')
grouped_df.describe()
# Out:
#                      matches                                                  \
#                        count       mean        std   min    25%   50%    75%
# league_name
# 2. Bundesliga           18.0  13.000000   0.000000  13.0  13.00  13.0  13.00
# 3. Liga                 20.0  14.700000   0.571241  13.0  14.75  15.0  15.00
# A-League                12.0  27.166667   1.403459  26.0  26.00  26.5  29.00
# Allsvenskan             16.0  30.000000   0.000000  30.0  30.00  30.0  30.00
# Bundesliga              30.0  12.200000   1.494819  11.0  11.00  11.0  14.00
# Championship            33.0  14.848485   1.839178  11.0  13.00  16.0  16.00
# División Profesional    12.0  42.000000   0.000000  42.0  42.00  42.0  42.00
# Ekstraklasa             18.0  14.666667   0.485071  14.0  14.00  15.0  15.00
# Eliteserien             16.0  28.000000   0.000000  28.0  28.00  28.0  28.00
# Eredivisie              18.0  11.777778   0.427793  11.0  12.00  12.0  12.00
# First Division          30.0  21.133333   9.640909  11.0  11.00  30.0  30.00
# First Division A        16.0  14.000000   0.000000  14.0  14.00  14.0  14.00
# First League            16.0  14.875000   0.341565  14.0  15.00  15.0  15.00
# HNL                     10.0  14.400000   0.699206  13.0  14.00  14.5  15.00
# J1 League               18.0  32.000000   0.000000  32.0  32.00  32.0  32.00
# K League 1              12.0  36.000000   0.000000  36.0  36.00  36.0  36.00
# LaLiga                  20.0  12.800000   0.410391  12.0  13.00  13.0  13.00
# LaLiga 2                22.0  15.000000   0.000000  15.0  15.00  15.0  15.00
# League One              24.0  16.333333   0.481543  16.0  16.00  16.0  17.00
# USL Championship      1414.0  1414.0  1414.0   1414.0
#
# [43 rows x 792 columns]

# %%
df['league_name'].value_counts()
# Out:
# Primera División        89
# Serie A                 56
# Premier League          44
# Serie B                 40
# Super League            40
# Championship            33
# Bundesliga              30
# First Division          30
# MLS                     29
# National League         24
# League Two              24
# League One              24
# USL Championship        24
# LaLiga 2                22
# LaLiga                  20
# Primera A               20
# Ligue 2                 20
# 3. Liga                 20
# Süper Lig               20
# Liga 1                  19
# Liga Portgual           18
# Ekstraklasa             18
# Eredivisie              18
# Liga MX                 18
# J1 League               18
# 2. Bundesliga           18
# Lique 1                 18
# Superettan              16
# Eliteserien             16
# First League            16
# First Division A        16
# Allsvenskan             16
# SuperLiga               16
# Liga de Expansión MX    15
# Super League 1          14
# Superligaen             12
# K League 1              12
# Premiership             12
# A-League                12
# División Profesional    12
# PrvaLiga                10
# Premier Division        10
# HNL                     10
# Name: league_name, dtype: int64

# %%
df = pd.read_csv('../data/raw/league_id2.csv')

# %%
df
# Out:
#     Wyscout ID           League Name  # Teams      Continent Confederation  \
# 0          146      Primera División       28  South America      CONMEBOL
# 1          152              A-League       12           Asia           AFC
# 2          168            Bundesliga       12         Europe          UEFA
# 3          198      First Division A       16         Europe          UEFA
# 4          209      Primera División       16  South America      CONMEBOL
# 5          255               Serie A       20  South America      CONMEBOL
# 6          256               Serie B       20  South America      CONMEBOL
# 7        43123        Premier League        8  North America      CONCACAF
# 8          284      Primera División       16  South America      CONMEBOL
# 9          287          Super League       16           Asia           AFC
# 10         295             Primera A       20  South America      CONMEBOL
# 11         301      Primera División       12  North America      CONCACAF
# 12         302                   HNL       10         Europe          UEFA
# 13         310        First Division       14         Europe          UEFA
# 14         323          First League       16         Europe          UEFA
# 15         335           Superligaen       12         Europe          UEFA
# 16         339               Serie A       16  South America      CONMEBOL
# 17         364        Premier League       20         Europe          UEFA
# 18         346          Championship       24         Europe          UEFA
# 19         358            League One       24         Europe          UEFA
# 20         359            League Two       24         Europe          UEFA
# 21         351       National League       24         Europe          UEFA
# 22         412               Lique 1       18         Europe          UEFA
# 23         413               Ligue 2       20         Europe          UEFA
# 24         426            Bundesliga       18         Europe          UEFA
# 25         423         2. Bundesliga       18         Europe          UEFA
# 26         425               3. Liga       20         Europe          UEFA
# 27         448        Super League 1       14         Europe          UEFA
# 28        1710          Super League       12           Asia           AFC
# 29         503      Premier Division       10         Europe          UEFA
# 30         524               Serie A       20         Europe          UEFA
# 31         527               Serie B       20         Europe          UEFA
# 32         534             J1 League       18           Asia           AFC
# 33         617               Liga MX       18  North America      CONCACAF
# 34         615  Liga de Expansión MX       15  North America      CONCACAF
# 35         635            Eredivisie       18         Europe          UEFA
# 36         669           Eliteserien       16         Europe          UEFA
# 37         665        First Division       16         Europe          UEFA
# 38         685  División Profesional       12  South America      CONMEBOL
# 39         688                Liga 1       19  South America      CONMEBOL
# 40         692           Ekstraklasa       18         Europe          UEFA
# 41         707         Liga Portgual       18         Europe          UEFA
# 42         729        Premier League       16         Europe          UEFA
# 43         750           Premiership       12         Europe          UEFA
# 44         744          Championship       10         Europe          UEFA
# 45         905             SuperLiga       16         Europe          UEFA
# 46         776              PrvaLiga       10         Europe          UEFA
# 47         551            K League 1       12           Asia           AFC
# 48         795                LaLiga       20         Europe          UEFA
# 49         797              LaLiga 2       22         Europe          UEFA
# 50         808           Allsvenskan       16         Europe          UEFA
# 51         818            Superettan       16         Europe          UEFA
# 52         830          Super League       12         Europe          UEFA
# 53         852             Süper Lig       20         Europe          UEFA
# 54         859        Premier League       16         Europe          UEFA
# 55         869                   MLS       29  North America      CONCACAF
# 56        1414      USL Championship       24  North America      CONCACAF
# 57         879      Primera División       16  South America      CONMEBOL
# 58         886      Primera División       15  South America      CONMEBOL
#
#    Wikipedia transfermarkt id            Country
# 0       Link             AR1N       Argentina 🇦🇷
# 1       Link             AUS1       Australia 🇦🇺
# 2       Link               A1         Austria 🇦🇹
# 3       Link              BE1         Belgium 🇧🇪
# 4       Link             BO1A         Bolivia 🇧🇴
# 5       Link             BRA1          Brazil 🇧🇷
# 6       Link             BRA2          Brazil 🇧🇷
# 7       Link             CDN1          Canada 🇨🇦
# 8       Link             CLP1           Chile 🇨🇱
# 9       Link              CSL           China 🇨🇳
# 10      Link             COL1        Colombia 🇨🇴
# 11      Link             CRPD      Costa Rica 🇨🇷
# 12      Link              KR1         Croatia 🇭🇷
# 13      Link             ZYP1          Cyprus 🇨🇾
# 14      Link              TS1  Czech Republic 🇨🇿
# 15      Link              DK1         Denmark 🇩🇰
# 16      Link             EL1A         Ecuador 🇪🇨
# 17      Link              GB1    England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 18      Link              GB2    England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 19      Link              GB3    England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 20      Link              GB4    England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 21      Link             CNAT    England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 22      Link              FR1          France 🇫🇷
# 23      Link              FR2          France 🇫🇷
# 24      Link               L1         Germany 🇩🇪
# 25      Link               L2         Germany 🇩🇪
# 26      Link               L3         Germany 🇩🇪
# 27      Link              GR1          Greece 🇬🇷
# 28      Link             IND1           India 🇮🇳
# 29      Link              IR1         Ireland 🇮🇪
# 30      Link              IT1           Italy 🇮🇹
# 31      Link              IT2           Italy 🇮🇹
# 32      Link             JAP1           Japan 🇯🇵
# 33      Link             MEXA          Mexico 🇲🇽
# 34      Link             MEXB          Mexico 🇲🇽
# 35      Link              NL1     Netherlands 🇳🇱
# 36      Link              NO1          Norway 🇳🇴
# 37      Link              NO2          Norway 🇳🇴
# 38      Link             PR1A        Paraguay 🇵🇾
# 39      Link             TDeA            Peru 🇵🇪
# 40      Link              PL1          Poland 🇵🇱
# 41      Link              PO1        Portugal 🇵🇹
# 42      Link              RU1          Russia 🇷🇺
# 43      Link              SC1   Scotland 🏴󠁧󠁢󠁳󠁣󠁴󠁿
# 44      Link              SC2   Scotland 🏴󠁧󠁢󠁳󠁣󠁴󠁿
# 45      Link             SER1          Serbia 🇷🇸
# 46      Link              SL1        Slovenia 🇸🇮
# 47      Link             RSK1     South Korea 🇰🇷
# 48      Link              ES1           Spain 🇪🇸
# 49      Link              ES2           Spain 🇪🇸
# 50      Link              SE1          Sweden 🇸🇪
# 51      Link              SE2          Sweden 🇸🇪
# 52      Link               C1     Switzerland 🇨🇭
# 53      Link              TR1          Turkey 🇹🇷
# 54      Link             UKR1         Ukraine 🇺🇦
# 55      Link             MLS1   United States 🇺🇸
# 56      Link              USL   United States 🇺🇸
# 57      Link             URU1         Uruguay 🇺🇾
# 58      Link             VZ1L       Venezuela 🇻🇪

# %%
df = pd.read_csv('../data/raw/team_market_value.csv')

# %%
df
# Out:
#      team_id                    name_id league_id  team_value  league_value
# 0        209             CA River Plate      AR1N     92750.0      897470.0
# 1        189            CA Boca Juniors      AR1N     79530.0      897470.0
# 2       1775  CA San Lorenzo de Almagro      AR1N     51830.0      897470.0
# 3       3938                CA Talleres      AR1N     49250.0      897470.0
# 4       1444                Racing Club      AR1N     49000.0      897470.0
# ..       ...                        ...       ...         ...           ...
# 470     9211     Bohemian Football Club       IR1         NaN       10780.0
# 471    27774               Cork City FC       IR1         NaN       10780.0
# 472     3909              Shelbourne FC       IR1         NaN       10780.0
# 473     6069  University College Dublin       IR1         NaN       10780.0
# 474     4277         Drogheda United FC       IR1         NaN       10780.0
#
# [475 rows x 5 columns]

# %%
df[['name', 'officialName', 'league_name', 'transfermarkt_id']]
# Out:
#              name                       officialName       league_name  \
# 0         Arsenal                 Arsenal de Sarandí  Primera División
# 1        Banfield                        CA Banfield  Primera División
# 2    Boca Juniors                    CA Boca Juniors  Primera División
# 3           Colón                  Colón de Santa Fe  Primera División
# 4     Estudiantes            Estudiantes de La Plata  Primera División
# ..            ...                                ...               ...
# 964   Cerro Largo            Cerro Largo Fútbol Club  Primera División
# 965        Racing          Racing Club de Montevideo  Primera División
# 966        La Luz                          La Luz FC  Primera División
# 967  Boston River  Club Atlético Boston River S.A.D.  Primera División
# 968        Torque             Montevideo City Torque  Primera División
#
#     transfermarkt_id
# 0               AR1N
# 1               AR1N
# 2               AR1N
# 3               AR1N
# 4               AR1N
# ..               ...
# 964             URU1
# 965             URU1
# 966             URU1
# 967             URU1
# 968             URU1
#
# [969 rows x 4 columns]

# %%
df[['name', 'league_name', 'linkupPlays']].sort_values(by='linkupPlays', ascending=False).head(10)
# Out:
#                  name       league_name  linkupPlays
# 907       Sporting KC               MLS          677
# 168            Junior         Primera A          670
# 558   Albirex Niigata         J1 League          666
# 912     Columbus Crew               MLS          665
# 2        Boca Juniors  Primera División          613
# 917           Toronto               MLS          597
# 85          São Paulo           Serie A          596
# 175       Millonarios         Primera A          592
# 154  Shandong Taishan      Super League          581
# 771             Seoul        K League 1          575
